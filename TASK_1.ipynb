# %%
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or 
# genders in a population

# %%
import pandas as pd
data = pd.read_csv("task pop.csv")
import matplotlib.pyplot as plt

# %%
data
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 7                   Arab World          ARB  Population, total    SP.POP.TOTL
# 8         United Arab Emirates          ARE  Population, total    SP.POP.TOTL
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0      54608      55811      56682      57475      58178      58782  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    9 non-null      object
#  1   Country Code    9 non-null      object
#  2   Indicator Name  9 non-null      object
#  3   Indicator Code  9 non-null      object
#  4   1960            9 non-null      int64
#  5   1961            9 non-null      int64
#  6   1962            9 non-null      int64
#  7   1963            9 non-null      int64
#  8   1964            9 non-null      int64
#  9   1965            9 non-null      int64
#  10  1966            9 non-null      int64
#  11  1967            9 non-null      int64
#  12  1968            9 non-null      int64
#  13  1969            9 non-null      int64
#  14  1970            9 non-null      int64
#  15  1971            9 non-null      int64
#  16  1972            9 non-null      int64
# ...

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   3.745491e+07  3.837132e+07  3.932974e+07  4.032631e+07  4.136262e+07
# std    5.330940e+07  5.465017e+07  5.605679e+07  5.751947e+07  5.904518e+07
# min    9.443000e+03  1.021600e+04  1.101400e+04  1.183900e+04  1.269000e+04
# 25%    1.334260e+05  1.409840e+05  1.488770e+05  1.570060e+05  1.653050e+05
# 50%    5.357195e+06  5.441333e+06  5.521400e+06  5.599827e+06  5.673199e+06
# 75%    9.335941e+07  9.576035e+07  9.826868e+07  1.008925e+08  1.036186e+08
# max    1.306926e+08  1.341692e+08  1.378356e+08  1.416305e+08  1.456060e+08
#
#                1965          1966          1967          1968          1969  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   4.243726e+07  4.354329e+07  4.468919e+07  4.588388e+07  4.712326e+07
# ...

# %%
population=data["2022"].sum()
population
# Out:
# 1764997761

# %%
# GROUPING DATA TOGETHER AND COUNTING OCCURENCES

country_population = data.groupby(['Country Name','2022']).size().unstack(fill_value=0)

# %%
# PLOTTING BAR CHART
country_population.plot(kind='bar',figsize=(10,6))
plt.xlabel("countries")
plt.ylabel("Count")
plt.title("population of countries")
plt.legend(title='population',labels = country_population.columns)
plt.show()

# %%
data_1 = pd.DataFrame({'Age':[25,30,28,32,22,31,35,29,49,26,30,49,57,34,55,26,37,47,42,45,47,45,52,65,37,27,52,50,
        36,29,62,67,66,67,60,35,22,21,42,23,27,29,31,30,32,35,23,39,40,56,65,60,70,15],
        'Gender':['Male','Female','Female','Male','Female','Male','Female',
        'Female','Male','Female','Male','Female','Female','Male','Female','Male','Female','Female','Male','Female','Male','Female','Female','Male','Male',
        'Male','Female','Female','Male','Female','Male','Female','Female','Male','Female','Male','Female','Female','Male','Female','Male','Female','Female','Male','Male','Male','Female','Female','Male','Male'
        ,'Male','Female','Female','Male']})

# %%
# GROUPING DATA TOGETHER AND COUNTING OCCURENCES

Age_Gender_counts = data_1.groupby(['Age','Gender']).size().unstack(fill_value=0)

# %%
#DEFINING COLORS FOR BARS
colors = ['Red','Blue']


# PLOTTING BAR CHART
ay = Age_Gender_counts.plot(kind='bar',figsize=(10,6),color=colors)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Distribution of Age and Gender")
plt.legend(title='Gender',labels = Age_Gender_counts.columns)
plt.show()
